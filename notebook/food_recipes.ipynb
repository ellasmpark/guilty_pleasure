# %%
import requests
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib

# %%
url = "https://www.skinnytaste.com/recipe-index/"

# %%
# This is where we do an HTTP request to get the HTML from the website
response = requests.get(url)

# And this is where we feed that HTML to the parser
soup = BeautifulSoup(response.content, "html.parser")

# %%
def food_recipe(food_choice,calories):

    recipe_key = '1c4f674c'
    recipe_id = 'f4063bcf2c650488f044cb2c2747fea3'
    calories = "400-500"
    food_choice = "chickpeas"

    url_2 = f"https://api.edamam.com/api/recipes/v2?type=public&q={food_choice}&app_id={recipe_key}&app_key={recipe_id}&calories={calories}"
    r_2 = requests.get(url_2).json()


    recipe_titles = r_2['hits']
    recipe=[]
    for dicts in recipe_titles:
        recipe.append(dicts['recipe']['label'])
    return recipe

# %%
recipe_key = '1c4f674c'
recipe_id = 'f4063bcf2c650488f044cb2c2747fea3'

user_tdee = 1800 #an example : in real life we will get it from user input (API)
junk_cals = 1200 #an example : in real life we will get it from user input (API)

calories = f"0-{user_tdee - junk_cals}"
food_choice = "chickpeas" #an example : in real life we will get it from user input (API)

url = f"https://api.edamam.com/api/recipes/v2?type=public&q={food_choice}&app_id={recipe_key}&app_key={recipe_id}&calories={calories}"
r = requests.get(url_2).json()

# %%
r['hits'][1]['recipe']
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_32244c2788e441a9b6c97fd87d1d83d0',
#  'label': 'Roasted Chickpeas',
# ...

# %%
recipe_titles = r['hits'][1]['recipe']['label']

# %%
recipe_titles
# Out:
# 'Roasted Chickpeas'

# %%
recipe_titles_1 = r['hits'][2]['recipe']['label']

# %%
recipe_titles_1
# Out:
# 'Achiote Chickpeas'

# %%
recipe_nutrients = r['hits'][1]['recipe']['totalNutrients']
# Out:
# {'ENERC_KCAL': {'label': 'Energy',
#   'quantity': 3373.8709757616034,
#   'unit': 'kcal'},
#  'FAT': {'label': 'Fat', 'quantity': 236.28666275750592, 'unit': 'g'},
#  'FASAT': {'label': 'Saturated', 'quantity': 15.558188682302834, 'unit': 'g'},
#  'FATRN': {'label': 'Trans', 'quantity': 1.7180800000290477, 'unit': 'g'},
#  'FAMS': {'label': 'Monounsaturated',
#   'quantity': 163.41686393190145,
#   'unit': 'g'},
#  'FAPU': {'label': 'Polyunsaturated',
#   'quantity': 42.572876274238155,
#   'unit': 'g'},
#  'CHOCDF': {'label': 'Carbs', 'quantity': 301.74126718096875, 'unit': 'g'},
#  'CHOCDF.net': {'label': 'Carbohydrates (net)',
#   'quantity': 272.03274024096874,
#   'unit': 'g'},
#  'FIBTG': {'label': 'Fiber', 'quantity': 29.708526940000006, 'unit': 'g'},
#  'SUGAR': {'label': 'Sugars', 'quantity': 217.27706609834374, 'unit': 'g'},
#  'SUGAR.added': {'label': 'Sugars, added', 'quantity': 199.6, 'unit': 'g'},
# ...

# %%
recipe_cals = recipe_nutrients['ENERC_KCAL']['quantity']
recipe_fats = recipe_nutrients['FAT']['quantity']
recipe_carbs = recipe_nutrients['CHOCDF']['quantity']
recipe_fibers = recipe_nutrients['FIBTG']['quantity']
recipe_proteins = recipe_nutrients['PROCNT']['quantity']

# %%
print(recipe_cals)
# Out:
# 3373.8709757616034

# %%
for r in r['hits'][r+1]['recipe']:
    recipe_name = r['hits'][r+1]['recipe']['label']
    recipe_nutrients = r['hits'][r+1]['recipe']['totalNutrients']
    recipe_cals = recipe_nutrients['ENERC_KCAL']['quantity']
    recipe_fats = recipe_nutrients['FAT']['quantity']
    recipe_carbs = recipe_nutrients['CHOCDF']['quantity']
    recipe_fibers = recipe_nutrients['FIBTG']['quantity']
    recipe_proteins = recipe_nutrients['PROCNT']['quantity']
    pd.DataFrame(recipe_name)

# %%
recipe_name = r['hits'][1]['recipe']['label']
recipe_nutrients = r['hits'][1]['recipe']['totalNutrients']
recipe_cals = recipe_nutrients['ENERC_KCAL']['quantity']
recipe_fats = recipe_nutrients['FAT']['quantity']
recipe_carbs = recipe_nutrients['CHOCDF']['quantity']
recipe_fibers = recipe_nutrients['FIBTG']['quantity']
recipe_proteins = recipe_nutrients['PROCNT']['quantity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 2
#       1 recipe_name = r['hits'][1]['recipe']['label']
# ----> 2 recipe_nutrients = r['hits'][1]['recipe']['totalNutrients']['quantity']
#       3 recipe_cals = recipe_nutrients['ENERC_KCAL']['quantity']
#       4 recipe_fats = recipe_nutrients['FAT']['quantity']
#
# KeyError: 'quantity'

# %%
df = pd.DataFrame(recipe_nutrients)
df
# Out:
#           ENERC_KCAL         FAT      FASAT  FATRN             FAMS  \
# label         Energy         Fat  Saturated  Trans  Monounsaturated
# quantity  13671.9905  229.984915   23.47946    0.0        59.203198
# unit            kcal           g          g      g                g
#
#                      FAPU       CHOCDF           CHOCDF.net     FIBTG  \
# label     Polyunsaturated        Carbs  Carbohydrates (net)     Fiber
# quantity        99.302404  2257.255315          1819.867815  437.3875
# unit                    g            g                    g         g
#
#                SUGAR  ...      VITB6A                     FOLDFE  \
# label         Sugars  ...  Vitamin B6  Folate equivalent (total)
# quantity  383.525665  ...   19.200037                 19963.6085
# unit               g  ...          mg                         µg
#
#                   FOLFD       FOLAC       VITB12       VITD     TOCPHA  \
# label     Folate (food)  Folic acid  Vitamin B12  Vitamin D  Vitamin E
# ...

# %%
df.drop(['label','unit'], inplace=True)

# %%
recipe_s = pd.Series([recipe_name])

# %%
df.set_index(recipe_s)
# Out:
#                    ENERC_KCAL         FAT     FASAT FATRN       FAMS  \
# Roasted Chickpeas  13671.9905  229.984915  23.47946   0.0  59.203198
#
#                         FAPU       CHOCDF   CHOCDF.net     FIBTG       SUGAR  \
# Roasted Chickpeas  99.302404  2257.255315  1819.867815  437.3875  383.525665
#
#                    ...     VITB6A      FOLDFE       FOLFD FOLAC VITB12 VITD  \
# Roasted Chickpeas  ...  19.200037  19963.6085  19963.6085   0.0    0.0  0.0
#
#                       TOCPHA     VITK1 Sugar.alcohol       WATER
# Roasted Chickpeas  31.336435  330.6932           0.0  275.360883
#
# [1 rows x 35 columns]
